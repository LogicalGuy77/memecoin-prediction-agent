# %%
# %pip install camel-ai[model_platforms,huggingface,web_tools] unstructured python-dotenv dune-client pandas numpy tabulate
# Out:
# Requirement already satisfied: unstructured in d:\coding\intern\ai-agent\.venv\lib\site-packages (0.17.2)
# Requirement already satisfied: python-dotenv in d:\coding\intern\ai-agent\.venv\lib\site-packages (1.1.0)
# Requirement already satisfied: dune-client in d:\coding\intern\ai-agent\.venv\lib\site-packages (1.7.9)
# Requirement already satisfied: pandas in d:\coding\intern\ai-agent\.venv\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy in d:\coding\intern\ai-agent\.venv\lib\site-packages (2.2.4)
# Requirement already satisfied: tabulate in d:\coding\intern\ai-agent\.venv\lib\site-packages (0.9.0)
# Requirement already satisfied: camel-ai[huggingface,model_platforms,web_tools] in d:\coding\intern\ai-agent\.venv\lib\site-packages (0.2.38)
# Requirement already satisfied: colorama<0.5,>=0.4.6 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from camel-ai[huggingface,model_platforms,web_tools]) (0.4.6)
# Requirement already satisfied: docstring-parser<0.16,>=0.15 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from camel-ai[huggingface,model_platforms,web_tools]) (0.15)
# Requirement already satisfied: httpx<1.0.0dev,>=0.28.0 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from camel-ai[huggingface,model_platforms,web_tools]) (0.28.1)
# Requirement already satisfied: jsonschema<5,>=4 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from camel-ai[huggingface,model_platforms,web_tools]) (4.23.0)
# Requirement already satisfied: openai<2,>=1.68.0 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from camel-ai[huggingface,model_platforms,web_tools]) (1.69.0)
# Requirement already satisfied: psutil<6,>=5.9.8 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from camel-ai[huggingface,model_platforms,web_tools]) (5.9.8)
# Requirement already satisfied: pydantic<2.10,>=1.9 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from camel-ai[huggingface,model_platforms,web_tools]) (2.9.2)
# Requirement already satisfied: tiktoken<0.8,>=0.7.0 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from camel-ai[huggingface,model_platforms,web_tools]) (0.7.0)
# Requirement already satisfied: accelerate<0.27,>=0.26.0 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from camel-ai[huggingface,model_platforms,web_tools]) (0.26.1)
# Requirement already satisfied: datasets<4,>=3 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from camel-ai[huggingface,model_platforms,web_tools]) (3.5.0)
# Requirement already satisfied: diffusers<0.26,>=0.25.0 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from camel-ai[huggingface,model_platforms,web_tools]) (0.25.1)
# Requirement already satisfied: opencv-python<5,>=4 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from camel-ai[huggingface,model_platforms,web_tools]) (4.11.0.86)
# Requirement already satisfied: sentencepiece<0.3,>=0.2 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from camel-ai[huggingface,model_platforms,web_tools]) (0.2.0)
# Requirement already satisfied: soundfile<0.14,>=0.13 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from camel-ai[huggingface,model_platforms,web_tools]) (0.13.1)
# Requirement already satisfied: torch in d:\coding\intern\ai-agent\.venv\lib\site-packages (from camel-ai[huggingface,model_platforms,web_tools]) (2.4.1)
# Requirement already satisfied: transformers<5,>=4 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from camel-ai[huggingface,model_platforms,web_tools]) (4.50.3)
# Requirement already satisfied: anthropic<0.50.0,>=0.47.0 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from camel-ai[huggingface,model_platforms,web_tools]) (0.49.0)
# Requirement already satisfied: cohere<6,>=5.11.0 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from camel-ai[huggingface,model_platforms,web_tools]) (5.14.0)
# Requirement already satisfied: fish-audio-sdk<2025,>=2024.12.5 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from camel-ai[huggingface,model_platforms,web_tools]) (2024.12.5)
# Requirement already satisfied: litellm<2,>=1.38.1 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from camel-ai[huggingface,model_platforms,web_tools]) (1.65.0)
# Requirement already satisfied: mistralai<2,>=1.1.0 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from camel-ai[huggingface,model_platforms,web_tools]) (1.5.2)
# Requirement already satisfied: reka-api<4,>=3.0.8 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from camel-ai[huggingface,model_platforms,web_tools]) (3.2.0)
# Requirement already satisfied: apify-client<2,>=1.8.1 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from camel-ai[huggingface,model_platforms,web_tools]) (1.9.2)
# Requirement already satisfied: beautifulsoup4<5,>=4 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from camel-ai[huggingface,model_platforms,web_tools]) (4.13.3)
# Requirement already satisfied: dappier<0.4,>=0.3.3 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from camel-ai[huggingface,model_platforms,web_tools]) (0.3.4)
# Requirement already satisfied: duckduckgo-search<7,>=6.3.5 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from camel-ai[huggingface,model_platforms,web_tools]) (6.4.2)
# Requirement already satisfied: fastapi>=0.115.11 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from camel-ai[huggingface,model_platforms,web_tools]) (0.115.12)
# Requirement already satisfied: firecrawl-py<2,>=1.0.0 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from camel-ai[huggingface,model_platforms,web_tools]) (1.6.8)
# Requirement already satisfied: googlemaps<5,>=4.10.0 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from camel-ai[huggingface,model_platforms,web_tools]) (4.10.0)
# Requirement already satisfied: html2text>=2024.2.26 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from camel-ai[huggingface,model_platforms,web_tools]) (2024.2.26)
# Requirement already satisfied: linkup-sdk<0.3,>=0.2.1 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from camel-ai[huggingface,model_platforms,web_tools]) (0.2.4)
# Requirement already satisfied: newspaper3k<0.3,>=0.2.8 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from camel-ai[huggingface,model_platforms,web_tools]) (0.2.8)
# Requirement already satisfied: playwright>=1.50.0 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from camel-ai[huggingface,model_platforms,web_tools]) (1.51.0)
# Requirement already satisfied: pyowm<4,>=3.3.0 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from camel-ai[huggingface,model_platforms,web_tools]) (3.3.0)
# Requirement already satisfied: requests-oauthlib<2,>=1.3.1 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from camel-ai[huggingface,model_platforms,web_tools]) (1.3.1)
# Requirement already satisfied: sympy<2,>=1.13.3 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from camel-ai[huggingface,model_platforms,web_tools]) (1.13.3)
# Requirement already satisfied: tavily-python<0.6,>=0.5.0 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from camel-ai[huggingface,model_platforms,web_tools]) (0.5.3)
# Requirement already satisfied: wikipedia<2,>=1 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from camel-ai[huggingface,model_platforms,web_tools]) (1.4.0)
# Requirement already satisfied: wolframalpha<6,>=5.0.0 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from camel-ai[huggingface,model_platforms,web_tools]) (5.1.3)
# Requirement already satisfied: chardet in d:\coding\intern\ai-agent\.venv\lib\site-packages (from unstructured) (5.2.0)
# Requirement already satisfied: filetype in d:\coding\intern\ai-agent\.venv\lib\site-packages (from unstructured) (1.2.0)
# Requirement already satisfied: python-magic in d:\coding\intern\ai-agent\.venv\lib\site-packages (from unstructured) (0.4.27)
# Requirement already satisfied: lxml in d:\coding\intern\ai-agent\.venv\lib\site-packages (from unstructured) (5.3.1)
# Requirement already satisfied: nltk in d:\coding\intern\ai-agent\.venv\lib\site-packages (from unstructured) (3.9.1)
# Requirement already satisfied: requests in d:\coding\intern\ai-agent\.venv\lib\site-packages (from unstructured) (2.32.3)
# Requirement already satisfied: emoji in d:\coding\intern\ai-agent\.venv\lib\site-packages (from unstructured) (2.14.1)
# Requirement already satisfied: dataclasses-json in d:\coding\intern\ai-agent\.venv\lib\site-packages (from unstructured) (0.6.7)
# Requirement already satisfied: python-iso639 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from unstructured) (2025.2.18)
# Requirement already satisfied: langdetect in d:\coding\intern\ai-agent\.venv\lib\site-packages (from unstructured) (1.0.9)
# Requirement already satisfied: rapidfuzz in d:\coding\intern\ai-agent\.venv\lib\site-packages (from unstructured) (3.12.2)
# Requirement already satisfied: backoff in d:\coding\intern\ai-agent\.venv\lib\site-packages (from unstructured) (2.2.1)
# Requirement already satisfied: typing-extensions in d:\coding\intern\ai-agent\.venv\lib\site-packages (from unstructured) (4.13.0)
# Requirement already satisfied: unstructured-client in d:\coding\intern\ai-agent\.venv\lib\site-packages (from unstructured) (0.28.1)
# Requirement already satisfied: wrapt in d:\coding\intern\ai-agent\.venv\lib\site-packages (from unstructured) (1.17.2)
# Requirement already satisfied: tqdm in d:\coding\intern\ai-agent\.venv\lib\site-packages (from unstructured) (4.67.1)
# Requirement already satisfied: python-oxmsg in d:\coding\intern\ai-agent\.venv\lib\site-packages (from unstructured) (0.0.2)
# Requirement already satisfied: html5lib in d:\coding\intern\ai-agent\.venv\lib\site-packages (from unstructured) (1.1)
# Requirement already satisfied: aiohttp>=3.8.3 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from dune-client) (3.11.14)
# Requirement already satisfied: types-python-dateutil>=2.8.19 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from dune-client) (2.9.0.20241206)
# Requirement already satisfied: types-PyYAML>=6.0.11 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from dune-client) (6.0.12.20250326)
# Requirement already satisfied: types-requests>=2.28.0 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from dune-client) (2.32.0.20250306)
# Requirement already satisfied: types-Deprecated>=1.2.9.3 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from dune-client) (1.2.15.20250304)
# Requirement already satisfied: types-setuptools>=68.2.0.0 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from dune-client) (76.0.0.20250313)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from dune-client) (2.9.0.post0)
# Requirement already satisfied: ndjson>=0.3.1 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from dune-client) (0.3.1)
# Requirement already satisfied: Deprecated>=1.2.0 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from dune-client) (1.2.18)
# Requirement already satisfied: pytz>=2020.1 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: packaging>=20.0 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from accelerate<0.27,>=0.26.0->camel-ai[huggingface,model_platforms,web_tools]) (24.2)
# Requirement already satisfied: pyyaml in d:\coding\intern\ai-agent\.venv\lib\site-packages (from accelerate<0.27,>=0.26.0->camel-ai[huggingface,model_platforms,web_tools]) (6.0.2)
# Requirement already satisfied: huggingface-hub in d:\coding\intern\ai-agent\.venv\lib\site-packages (from accelerate<0.27,>=0.26.0->camel-ai[huggingface,model_platforms,web_tools]) (0.29.3)
# Requirement already satisfied: safetensors>=0.3.1 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from accelerate<0.27,>=0.26.0->camel-ai[huggingface,model_platforms,web_tools]) (0.5.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from aiohttp>=3.8.3->dune-client) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from aiohttp>=3.8.3->dune-client) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from aiohttp>=3.8.3->dune-client) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from aiohttp>=3.8.3->dune-client) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from aiohttp>=3.8.3->dune-client) (6.2.0)
# Requirement already satisfied: propcache>=0.2.0 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from aiohttp>=3.8.3->dune-client) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from aiohttp>=3.8.3->dune-client) (1.18.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from anthropic<0.50.0,>=0.47.0->camel-ai[huggingface,model_platforms,web_tools]) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from anthropic<0.50.0,>=0.47.0->camel-ai[huggingface,model_platforms,web_tools]) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from anthropic<0.50.0,>=0.47.0->camel-ai[huggingface,model_platforms,web_tools]) (0.9.0)
# Requirement already satisfied: sniffio in d:\coding\intern\ai-agent\.venv\lib\site-packages (from anthropic<0.50.0,>=0.47.0->camel-ai[huggingface,model_platforms,web_tools]) (1.3.1)
# Requirement already satisfied: apify-shared>=1.1.2 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from apify-client<2,>=1.8.1->camel-ai[huggingface,model_platforms,web_tools]) (1.3.2)
# Requirement already satisfied: more_itertools>=10.0.0 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from apify-client<2,>=1.8.1->camel-ai[huggingface,model_platforms,web_tools]) (10.6.0)
# Requirement already satisfied: soupsieve>1.2 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from beautifulsoup4<5,>=4->camel-ai[huggingface,model_platforms,web_tools]) (2.6)
# Requirement already satisfied: fastavro<2.0.0,>=1.9.4 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from cohere<6,>=5.11.0->camel-ai[huggingface,model_platforms,web_tools]) (1.10.0)
# Requirement already satisfied: httpx-sse==0.4.0 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from cohere<6,>=5.11.0->camel-ai[huggingface,model_platforms,web_tools]) (0.4.0)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.18.2 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from cohere<6,>=5.11.0->camel-ai[huggingface,model_platforms,web_tools]) (2.23.4)
# Requirement already satisfied: tokenizers<1,>=0.15 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from cohere<6,>=5.11.0->camel-ai[huggingface,model_platforms,web_tools]) (0.21.1)
# Requirement already satisfied: asyncio<4.0.0,>=3.4.3 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from dappier<0.4,>=0.3.3->camel-ai[huggingface,model_platforms,web_tools]) (3.4.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from dataclasses-json->unstructured) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from dataclasses-json->unstructured) (0.9.0)
# Requirement already satisfied: filelock in d:\coding\intern\ai-agent\.venv\lib\site-packages (from datasets<4,>=3->camel-ai[huggingface,model_platforms,web_tools]) (3.18.0)
# Requirement already satisfied: pyarrow>=15.0.0 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from datasets<4,>=3->camel-ai[huggingface,model_platforms,web_tools]) (19.0.1)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from datasets<4,>=3->camel-ai[huggingface,model_platforms,web_tools]) (0.3.8)
# Requirement already satisfied: xxhash in d:\coding\intern\ai-agent\.venv\lib\site-packages (from datasets<4,>=3->camel-ai[huggingface,model_platforms,web_tools]) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from datasets<4,>=3->camel-ai[huggingface,model_platforms,web_tools]) (0.70.16)
# Requirement already satisfied: fsspec<=2024.12.0,>=2023.1.0 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets<4,>=3->camel-ai[huggingface,model_platforms,web_tools]) (2024.12.0)
# Requirement already satisfied: importlib-metadata in d:\coding\intern\ai-agent\.venv\lib\site-packages (from diffusers<0.26,>=0.25.0->camel-ai[huggingface,model_platforms,web_tools]) (8.6.1)
# Requirement already satisfied: regex!=2019.12.17 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from diffusers<0.26,>=0.25.0->camel-ai[huggingface,model_platforms,web_tools]) (2024.11.6)
# Requirement already satisfied: Pillow in d:\coding\intern\ai-agent\.venv\lib\site-packages (from diffusers<0.26,>=0.25.0->camel-ai[huggingface,model_platforms,web_tools]) (11.1.0)
# Requirement already satisfied: click>=8.1.7 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from duckduckgo-search<7,>=6.3.5->camel-ai[huggingface,model_platforms,web_tools]) (8.1.8)
# Requirement already satisfied: primp>=0.9.1 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from duckduckgo-search<7,>=6.3.5->camel-ai[huggingface,model_platforms,web_tools]) (0.14.0)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from fastapi>=0.115.11->camel-ai[huggingface,model_platforms,web_tools]) (0.46.1)
# Requirement already satisfied: websockets in d:\coding\intern\ai-agent\.venv\lib\site-packages (from firecrawl-py<2,>=1.0.0->camel-ai[huggingface,model_platforms,web_tools]) (15.0.1)
# Requirement already satisfied: nest-asyncio in d:\coding\intern\ai-agent\.venv\lib\site-packages (from firecrawl-py<2,>=1.0.0->camel-ai[huggingface,model_platforms,web_tools]) (1.6.0)
# Requirement already satisfied: ormsgpack>=1.5.0 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from fish-audio-sdk<2025,>=2024.12.5->camel-ai[huggingface,model_platforms,web_tools]) (1.9.1)
# Requirement already satisfied: httpx-ws>=0.6.2 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from fish-audio-sdk<2025,>=2024.12.5->camel-ai[huggingface,model_platforms,web_tools]) (0.7.2)
# Requirement already satisfied: certifi in d:\coding\intern\ai-agent\.venv\lib\site-packages (from httpx<1.0.0dev,>=0.28.0->camel-ai[huggingface,model_platforms,web_tools]) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in d:\coding\intern\ai-agent\.venv\lib\site-packages (from httpx<1.0.0dev,>=0.28.0->camel-ai[huggingface,model_platforms,web_tools]) (1.0.7)
# Requirement already satisfied: idna in d:\coding\intern\ai-agent\.venv\lib\site-packages (from httpx<1.0.0dev,>=0.28.0->camel-ai[huggingface,model_platforms,web_tools]) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from httpcore==1.*->httpx<1.0.0dev,>=0.28.0->camel-ai[huggingface,model_platforms,web_tools]) (0.14.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from jsonschema<5,>=4->camel-ai[huggingface,model_platforms,web_tools]) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from jsonschema<5,>=4->camel-ai[huggingface,model_platforms,web_tools]) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from jsonschema<5,>=4->camel-ai[huggingface,model_platforms,web_tools]) (0.24.0)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.2 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from litellm<2,>=1.38.1->camel-ai[huggingface,model_platforms,web_tools]) (3.1.6)
# Requirement already satisfied: eval-type-backport>=0.2.0 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from mistralai<2,>=1.1.0->camel-ai[huggingface,model_platforms,web_tools]) (0.2.2)
# Requirement already satisfied: jsonpath-python>=1.0.6 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from mistralai<2,>=1.1.0->camel-ai[huggingface,model_platforms,web_tools]) (1.0.6)
# Requirement already satisfied: cssselect>=0.9.2 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from newspaper3k<0.3,>=0.2.8->camel-ai[huggingface,model_platforms,web_tools]) (1.3.0)
# Requirement already satisfied: feedparser>=5.2.1 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from newspaper3k<0.3,>=0.2.8->camel-ai[huggingface,model_platforms,web_tools]) (6.0.11)
# Requirement already satisfied: tldextract>=2.0.1 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from newspaper3k<0.3,>=0.2.8->camel-ai[huggingface,model_platforms,web_tools]) (5.1.3)
# Requirement already satisfied: feedfinder2>=0.0.4 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from newspaper3k<0.3,>=0.2.8->camel-ai[huggingface,model_platforms,web_tools]) (0.0.4)
# Requirement already satisfied: jieba3k>=0.35.1 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from newspaper3k<0.3,>=0.2.8->camel-ai[huggingface,model_platforms,web_tools]) (0.35.1)
# Requirement already satisfied: tinysegmenter==0.3 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from newspaper3k<0.3,>=0.2.8->camel-ai[huggingface,model_platforms,web_tools]) (0.3)
# Requirement already satisfied: joblib in d:\coding\intern\ai-agent\.venv\lib\site-packages (from nltk->unstructured) (1.4.2)
# Requirement already satisfied: pyee<13,>=12 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from playwright>=1.50.0->camel-ai[huggingface,model_platforms,web_tools]) (12.1.1)
# Requirement already satisfied: greenlet<4.0.0,>=3.1.1 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from playwright>=1.50.0->camel-ai[huggingface,model_platforms,web_tools]) (3.1.1)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from pydantic<2.10,>=1.9->camel-ai[huggingface,model_platforms,web_tools]) (0.7.0)
# Requirement already satisfied: geojson<3,>=2.3.0 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from pyowm<4,>=3.3.0->camel-ai[huggingface,model_platforms,web_tools]) (2.5.0)
# Requirement already satisfied: PySocks<2,>=1.7.1 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from pyowm<4,>=3.3.0->camel-ai[huggingface,model_platforms,web_tools]) (1.7.1)
# Requirement already satisfied: six>=1.5 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from python-dateutil>=2.8.2->dune-client) (1.17.0)
# Requirement already satisfied: urllib3>=2.0.7 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from reka-api<4,>=3.0.8->camel-ai[huggingface,model_platforms,web_tools]) (2.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from requests->unstructured) (3.4.1)
# Requirement already satisfied: oauthlib>=3.0.0 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from requests-oauthlib<2,>=1.3.1->camel-ai[huggingface,model_platforms,web_tools]) (3.2.2)
# Requirement already satisfied: cffi>=1.0 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from soundfile<0.14,>=0.13->camel-ai[huggingface,model_platforms,web_tools]) (1.17.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from sympy<2,>=1.13.3->camel-ai[huggingface,model_platforms,web_tools]) (1.3.0)
# Requirement already satisfied: networkx in d:\coding\intern\ai-agent\.venv\lib\site-packages (from torch->camel-ai[huggingface,model_platforms,web_tools]) (3.4.2)
# Requirement already satisfied: setuptools in d:\coding\intern\ai-agent\.venv\lib\site-packages (from torch->camel-ai[huggingface,model_platforms,web_tools]) (78.1.0)
# Requirement already satisfied: xmltodict in d:\coding\intern\ai-agent\.venv\lib\site-packages (from wolframalpha<6,>=5.0.0->camel-ai[huggingface,model_platforms,web_tools]) (0.14.2)
# Requirement already satisfied: jaraco.context in d:\coding\intern\ai-agent\.venv\lib\site-packages (from wolframalpha<6,>=5.0.0->camel-ai[huggingface,model_platforms,web_tools]) (6.0.1)
# Requirement already satisfied: webencodings in d:\coding\intern\ai-agent\.venv\lib\site-packages (from html5lib->unstructured) (0.5.1)
# Requirement already satisfied: olefile in d:\coding\intern\ai-agent\.venv\lib\site-packages (from python-oxmsg->unstructured) (0.47)
# Requirement already satisfied: aiofiles>=24.1.0 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from unstructured-client->unstructured) (24.1.0)
# Requirement already satisfied: cryptography>=3.1 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from unstructured-client->unstructured) (44.0.2)
# Requirement already satisfied: pypdf>=4.0 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from unstructured-client->unstructured) (5.4.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from unstructured-client->unstructured) (1.0.0)
# Requirement already satisfied: pycparser in d:\coding\intern\ai-agent\.venv\lib\site-packages (from cffi>=1.0->soundfile<0.14,>=0.13->camel-ai[huggingface,model_platforms,web_tools]) (2.22)
# Requirement already satisfied: sgmllib3k in d:\coding\intern\ai-agent\.venv\lib\site-packages (from feedparser>=5.2.1->newspaper3k<0.3,>=0.2.8->camel-ai[huggingface,model_platforms,web_tools]) (1.0.0)
# Requirement already satisfied: wsproto in d:\coding\intern\ai-agent\.venv\lib\site-packages (from httpx-ws>=0.6.2->fish-audio-sdk<2025,>=2024.12.5->camel-ai[huggingface,model_platforms,web_tools]) (1.2.0)
# Requirement already satisfied: zipp>=3.20 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from importlib-metadata->diffusers<0.26,>=0.25.0->camel-ai[huggingface,model_platforms,web_tools]) (3.21.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from jinja2<4.0.0,>=3.1.2->litellm<2,>=1.38.1->camel-ai[huggingface,model_platforms,web_tools]) (3.0.2)
# Requirement already satisfied: requests-file>=1.4 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from tldextract>=2.0.1->newspaper3k<0.3,>=0.2.8->camel-ai[huggingface,model_platforms,web_tools]) (2.1.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in d:\coding\intern\ai-agent\.venv\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->unstructured) (1.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Importing environment variables

# %%
# %load_ext dotenv
# %dotenv

import os
import pandas as pd
import numpy as np

# %% [markdown]
# # Preparing memecoin data

# %% [markdown]
# ## Connecting to dune client

# %%
from dune_client.client import DuneClient
dune = DuneClient(os.environ['DUNE_API_KEY'])

# %% [markdown]
# ## Querying 24H Memecoin Growth Holder

# %%
from dune_client.query import QueryBase
from dune_client.types import QueryParameter

query_90d = QueryBase(
    name="90d_memecoin_growth_holder",
    query_id=4948190
)

query_30d = QueryBase(
    name="30d_memecoin_growth_holder",
    query_id=4948159
)

# 7-day data
query_7d = QueryBase(
    name="7d_memecoin_growth_holder",
    query_id=4947030
)

# 24-hour data
query_24h = QueryBase(
    name="24h_memecoin_growth_holder",
    query_id=4947022
)

# %%
response_90d = dune.run_query_dataframe(query_90d)
response_30d = dune.run_query_dataframe(query_30d)
response_7d = dune.run_query_dataframe(query_7d)
response_24h = dune.run_query_dataframe(query_24h)
# Out:
# 2025-04-09 00:09:32,257 INFO dune_client.api.base executing 4948190 on medium cluster
# 2025-04-09 00:09:33,166 INFO dune_client.api.base waiting for query execution 01JRBB6HQ4NHAVR3GT4PKM5FJH to complete: ExecutionState.PENDING (queue position: 34)
# 2025-04-09 00:09:34,368 INFO dune_client.api.base waiting for query execution 01JRBB6HQ4NHAVR3GT4PKM5FJH to complete: ExecutionState.PENDING (queue position: 34)
# 2025-04-09 00:09:35,549 INFO dune_client.api.base waiting for query execution 01JRBB6HQ4NHAVR3GT4PKM5FJH to complete: ExecutionState.EXECUTING
# 2025-04-09 00:09:36,734 INFO dune_client.api.base waiting for query execution 01JRBB6HQ4NHAVR3GT4PKM5FJH to complete: ExecutionState.EXECUTING
# 2025-04-09 00:09:37,922 INFO dune_client.api.base waiting for query execution 01JRBB6HQ4NHAVR3GT4PKM5FJH to complete: ExecutionState.EXECUTING
# 2025-04-09 00:09:39,116 INFO dune_client.api.base waiting for query execution 01JRBB6HQ4NHAVR3GT4PKM5FJH to complete: ExecutionState.EXECUTING
# 2025-04-09 00:09:40,311 INFO dune_client.api.base waiting for query execution 01JRBB6HQ4NHAVR3GT4PKM5FJH to complete: ExecutionState.EXECUTING
# 2025-04-09 00:09:41,492 INFO dune_client.api.base waiting for query execution 01JRBB6HQ4NHAVR3GT4PKM5FJH to complete: ExecutionState.EXECUTING
# 2025-04-09 00:09:42,679 INFO dune_client.api.base waiting for query execution 01JRBB6HQ4NHAVR3GT4PKM5FJH to complete: ExecutionState.EXECUTING
# 2025-04-09 00:09:43,875 INFO dune_client.api.base waiting for query execution 01JRBB6HQ4NHAVR3GT4PKM5FJH to complete: ExecutionState.EXECUTING
# 2025-04-09 00:09:45,060 INFO dune_client.api.base waiting for query execution 01JRBB6HQ4NHAVR3GT4PKM5FJH to complete: ExecutionState.EXECUTING
# 2025-04-09 00:09:46,246 INFO dune_client.api.base waiting for query execution 01JRBB6HQ4NHAVR3GT4PKM5FJH to complete: ExecutionState.EXECUTING
# 2025-04-09 00:09:47,432 INFO dune_client.api.base waiting for query execution 01JRBB6HQ4NHAVR3GT4PKM5FJH to complete: ExecutionState.EXECUTING
# 2025-04-09 00:09:48,637 INFO dune_client.api.base waiting for query execution 01JRBB6HQ4NHAVR3GT4PKM5FJH to complete: ExecutionState.EXECUTING
# 2025-04-09 00:09:49,822 INFO dune_client.api.base waiting for query execution 01JRBB6HQ4NHAVR3GT4PKM5FJH to complete: ExecutionState.EXECUTING
# 2025-04-09 00:09:50,998 INFO dune_client.api.base waiting for query execution 01JRBB6HQ4NHAVR3GT4PKM5FJH to complete: ExecutionState.EXECUTING
# 2025-04-09 00:09:52,178 INFO dune_client.api.base waiting for query execution 01JRBB6HQ4NHAVR3GT4PKM5FJH to complete: ExecutionState.EXECUTING
# 2025-04-09 00:09:53,367 INFO dune_client.api.base waiting for query execution 01JRBB6HQ4NHAVR3GT4PKM5FJH to complete: ExecutionState.EXECUTING
# 2025-04-09 00:09:54,547 INFO dune_client.api.base waiting for query execution 01JRBB6HQ4NHAVR3GT4PKM5FJH to complete: ExecutionState.EXECUTING
# 2025-04-09 00:09:55,734 INFO dune_client.api.base waiting for query execution 01JRBB6HQ4NHAVR3GT4PKM5FJH to complete: ExecutionState.EXECUTING
# 2025-04-09 00:09:56,923 INFO dune_client.api.base waiting for query execution 01JRBB6HQ4NHAVR3GT4PKM5FJH to complete: ExecutionState.EXECUTING
# 2025-04-09 00:09:58,109 INFO dune_client.api.base waiting for query execution 01JRBB6HQ4NHAVR3GT4PKM5FJH to complete: ExecutionState.EXECUTING
# 2025-04-09 00:09:59,294 INFO dune_client.api.base waiting for query execution 01JRBB6HQ4NHAVR3GT4PKM5FJH to complete: ExecutionState.EXECUTING
# 2025-04-09 00:10:00,478 INFO dune_client.api.base waiting for query execution 01JRBB6HQ4NHAVR3GT4PKM5FJH to complete: ExecutionState.EXECUTING
# 2025-04-09 00:10:01,666 INFO dune_client.api.base waiting for query execution 01JRBB6HQ4NHAVR3GT4PKM5FJH to complete: ExecutionState.EXECUTING
# 2025-04-09 00:10:02,847 INFO dune_client.api.base waiting for query execution 01JRBB6HQ4NHAVR3GT4PKM5FJH to complete: ExecutionState.EXECUTING
# 2025-04-09 00:10:04,037 INFO dune_client.api.base waiting for query execution 01JRBB6HQ4NHAVR3GT4PKM5FJH to complete: ExecutionState.EXECUTING
# 2025-04-09 00:10:05,220 INFO dune_client.api.base waiting for query execution 01JRBB6HQ4NHAVR3GT4PKM5FJH to complete: ExecutionState.EXECUTING
# 2025-04-09 00:10:06,408 INFO dune_client.api.base waiting for query execution 01JRBB6HQ4NHAVR3GT4PKM5FJH to complete: ExecutionState.EXECUTING
# 2025-04-09 00:10:07,671 INFO dune_client.api.base waiting for query execution 01JRBB6HQ4NHAVR3GT4PKM5FJH to complete: ExecutionState.EXECUTING
# 2025-04-09 00:10:08,857 INFO dune_client.api.base waiting for query execution 01JRBB6HQ4NHAVR3GT4PKM5FJH to complete: ExecutionState.EXECUTING
# 2025-04-09 00:10:10,040 INFO dune_client.api.base waiting for query execution 01JRBB6HQ4NHAVR3GT4PKM5FJH to complete: ExecutionState.EXECUTING
# 2025-04-09 00:10:11,223 INFO dune_client.api.base waiting for query execution 01JRBB6HQ4NHAVR3GT4PKM5FJH to complete: ExecutionState.EXECUTING
# 2025-04-09 00:10:12,401 INFO dune_client.api.base waiting for query execution 01JRBB6HQ4NHAVR3GT4PKM5FJH to complete: ExecutionState.EXECUTING
# 2025-04-09 00:10:13,603 INFO dune_client.api.base waiting for query execution 01JRBB6HQ4NHAVR3GT4PKM5FJH to complete: ExecutionState.EXECUTING
# 2025-04-09 00:10:14,829 INFO dune_client.api.base waiting for query execution 01JRBB6HQ4NHAVR3GT4PKM5FJH to complete: ExecutionState.EXECUTING
# 2025-04-09 00:10:16,018 INFO dune_client.api.base waiting for query execution 01JRBB6HQ4NHAVR3GT4PKM5FJH to complete: ExecutionState.EXECUTING
# 2025-04-09 00:10:17,212 INFO dune_client.api.base waiting for query execution 01JRBB6HQ4NHAVR3GT4PKM5FJH to complete: ExecutionState.EXECUTING
# 2025-04-09 00:10:18,458 INFO dune_client.api.base waiting for query execution 01JRBB6HQ4NHAVR3GT4PKM5FJH to complete: ExecutionState.EXECUTING
# 2025-04-09 00:10:19,977 INFO dune_client.api.base executing 4948159 on medium cluster
# 2025-04-09 00:10:20,378 INFO dune_client.api.base waiting for query execution 01JRBB7ZXW6Z1P8E3TBH46YDKG to complete: ExecutionState.PENDING (queue position: 33)
# 2025-04-09 00:10:21,570 INFO dune_client.api.base waiting for query execution 01JRBB7ZXW6Z1P8E3TBH46YDKG to complete: ExecutionState.PENDING (queue position: 33)
# 2025-04-09 00:10:22,759 INFO dune_client.api.base waiting for query execution 01JRBB7ZXW6Z1P8E3TBH46YDKG to complete: ExecutionState.PENDING (queue position: 33)
# 2025-04-09 00:10:23,937 INFO dune_client.api.base waiting for query execution 01JRBB7ZXW6Z1P8E3TBH46YDKG to complete: ExecutionState.EXECUTING
# 2025-04-09 00:10:25,122 INFO dune_client.api.base waiting for query execution 01JRBB7ZXW6Z1P8E3TBH46YDKG to complete: ExecutionState.EXECUTING
# 2025-04-09 00:10:26,315 INFO dune_client.api.base waiting for query execution 01JRBB7ZXW6Z1P8E3TBH46YDKG to complete: ExecutionState.EXECUTING
# 2025-04-09 00:10:27,499 INFO dune_client.api.base waiting for query execution 01JRBB7ZXW6Z1P8E3TBH46YDKG to complete: ExecutionState.EXECUTING
# 2025-04-09 00:10:28,688 INFO dune_client.api.base waiting for query execution 01JRBB7ZXW6Z1P8E3TBH46YDKG to complete: ExecutionState.EXECUTING
# 2025-04-09 00:10:29,872 INFO dune_client.api.base waiting for query execution 01JRBB7ZXW6Z1P8E3TBH46YDKG to complete: ExecutionState.EXECUTING
# 2025-04-09 00:10:31,055 INFO dune_client.api.base waiting for query execution 01JRBB7ZXW6Z1P8E3TBH46YDKG to complete: ExecutionState.EXECUTING
# 2025-04-09 00:10:32,238 INFO dune_client.api.base waiting for query execution 01JRBB7ZXW6Z1P8E3TBH46YDKG to complete: ExecutionState.EXECUTING
# 2025-04-09 00:10:33,425 INFO dune_client.api.base waiting for query execution 01JRBB7ZXW6Z1P8E3TBH46YDKG to complete: ExecutionState.EXECUTING
# 2025-04-09 00:10:34,611 INFO dune_client.api.base waiting for query execution 01JRBB7ZXW6Z1P8E3TBH46YDKG to complete: ExecutionState.EXECUTING
# 2025-04-09 00:10:35,797 INFO dune_client.api.base waiting for query execution 01JRBB7ZXW6Z1P8E3TBH46YDKG to complete: ExecutionState.EXECUTING
# 2025-04-09 00:10:36,980 INFO dune_client.api.base waiting for query execution 01JRBB7ZXW6Z1P8E3TBH46YDKG to complete: ExecutionState.EXECUTING
# 2025-04-09 00:10:38,205 INFO dune_client.api.base waiting for query execution 01JRBB7ZXW6Z1P8E3TBH46YDKG to complete: ExecutionState.EXECUTING
# 2025-04-09 00:10:39,391 INFO dune_client.api.base waiting for query execution 01JRBB7ZXW6Z1P8E3TBH46YDKG to complete: ExecutionState.EXECUTING
# 2025-04-09 00:10:40,568 INFO dune_client.api.base waiting for query execution 01JRBB7ZXW6Z1P8E3TBH46YDKG to complete: ExecutionState.EXECUTING
# 2025-04-09 00:10:41,765 INFO dune_client.api.base waiting for query execution 01JRBB7ZXW6Z1P8E3TBH46YDKG to complete: ExecutionState.EXECUTING
# 2025-04-09 00:10:42,948 INFO dune_client.api.base waiting for query execution 01JRBB7ZXW6Z1P8E3TBH46YDKG to complete: ExecutionState.EXECUTING
# 2025-04-09 00:10:44,135 INFO dune_client.api.base waiting for query execution 01JRBB7ZXW6Z1P8E3TBH46YDKG to complete: ExecutionState.EXECUTING
# 2025-04-09 00:10:45,318 INFO dune_client.api.base waiting for query execution 01JRBB7ZXW6Z1P8E3TBH46YDKG to complete: ExecutionState.EXECUTING
# 2025-04-09 00:10:46,500 INFO dune_client.api.base waiting for query execution 01JRBB7ZXW6Z1P8E3TBH46YDKG to complete: ExecutionState.EXECUTING
# 2025-04-09 00:10:47,694 INFO dune_client.api.base waiting for query execution 01JRBB7ZXW6Z1P8E3TBH46YDKG to complete: ExecutionState.EXECUTING
# 2025-04-09 00:11:05,515 INFO dune_client.api.base executing 4947030 on medium cluster
# 2025-04-09 00:11:05,923 INFO dune_client.api.base waiting for query execution 01JRBB9CCXNB0N7QBHZDN25KFX to complete: ExecutionState.PENDING (queue position: 45)
# 2025-04-09 00:11:07,111 INFO dune_client.api.base waiting for query execution 01JRBB9CCXNB0N7QBHZDN25KFX to complete: ExecutionState.PENDING (queue position: 45)
# 2025-04-09 00:11:08,300 INFO dune_client.api.base waiting for query execution 01JRBB9CCXNB0N7QBHZDN25KFX to complete: ExecutionState.EXECUTING
# 2025-04-09 00:11:09,483 INFO dune_client.api.base waiting for query execution 01JRBB9CCXNB0N7QBHZDN25KFX to complete: ExecutionState.EXECUTING
# 2025-04-09 00:11:10,668 INFO dune_client.api.base waiting for query execution 01JRBB9CCXNB0N7QBHZDN25KFX to complete: ExecutionState.EXECUTING
# 2025-04-09 00:11:11,850 INFO dune_client.api.base waiting for query execution 01JRBB9CCXNB0N7QBHZDN25KFX to complete: ExecutionState.EXECUTING
# 2025-04-09 00:11:13,036 INFO dune_client.api.base waiting for query execution 01JRBB9CCXNB0N7QBHZDN25KFX to complete: ExecutionState.EXECUTING
# 2025-04-09 00:11:14,220 INFO dune_client.api.base waiting for query execution 01JRBB9CCXNB0N7QBHZDN25KFX to complete: ExecutionState.EXECUTING
# 2025-04-09 00:11:15,402 INFO dune_client.api.base waiting for query execution 01JRBB9CCXNB0N7QBHZDN25KFX to complete: ExecutionState.EXECUTING
# 2025-04-09 00:11:16,594 INFO dune_client.api.base waiting for query execution 01JRBB9CCXNB0N7QBHZDN25KFX to complete: ExecutionState.EXECUTING
# 2025-04-09 00:11:17,791 INFO dune_client.api.base waiting for query execution 01JRBB9CCXNB0N7QBHZDN25KFX to complete: ExecutionState.EXECUTING
# 2025-04-09 00:11:18,972 INFO dune_client.api.base waiting for query execution 01JRBB9CCXNB0N7QBHZDN25KFX to complete: ExecutionState.EXECUTING
# 2025-04-09 00:11:20,151 INFO dune_client.api.base waiting for query execution 01JRBB9CCXNB0N7QBHZDN25KFX to complete: ExecutionState.EXECUTING
# 2025-04-09 00:11:21,341 INFO dune_client.api.base waiting for query execution 01JRBB9CCXNB0N7QBHZDN25KFX to complete: ExecutionState.EXECUTING
# 2025-04-09 00:11:22,525 INFO dune_client.api.base waiting for query execution 01JRBB9CCXNB0N7QBHZDN25KFX to complete: ExecutionState.EXECUTING
# 2025-04-09 00:11:24,237 INFO dune_client.api.base waiting for query execution 01JRBB9CCXNB0N7QBHZDN25KFX to complete: ExecutionState.EXECUTING
# 2025-04-09 00:11:25,423 INFO dune_client.api.base waiting for query execution 01JRBB9CCXNB0N7QBHZDN25KFX to complete: ExecutionState.EXECUTING
# 2025-04-09 00:11:26,912 INFO dune_client.api.base executing 4947022 on medium cluster
# 2025-04-09 00:11:27,308 INFO dune_client.api.base waiting for query execution 01JRBBA19D4Z9MYVY461K94KXC to complete: ExecutionState.PENDING (queue position: 44)
# 2025-04-09 00:11:28,501 INFO dune_client.api.base waiting for query execution 01JRBBA19D4Z9MYVY461K94KXC to complete: ExecutionState.PENDING (queue position: 44)
# 2025-04-09 00:11:29,694 INFO dune_client.api.base waiting for query execution 01JRBBA19D4Z9MYVY461K94KXC to complete: ExecutionState.EXECUTING
# 2025-04-09 00:11:30,882 INFO dune_client.api.base waiting for query execution 01JRBBA19D4Z9MYVY461K94KXC to complete: ExecutionState.EXECUTING
# 2025-04-09 00:11:32,092 INFO dune_client.api.base waiting for query execution 01JRBBA19D4Z9MYVY461K94KXC to complete: ExecutionState.EXECUTING
# 2025-04-09 00:11:33,271 INFO dune_client.api.base waiting for query execution 01JRBBA19D4Z9MYVY461K94KXC to complete: ExecutionState.EXECUTING
# 2025-04-09 00:11:34,454 INFO dune_client.api.base waiting for query execution 01JRBBA19D4Z9MYVY461K94KXC to complete: ExecutionState.EXECUTING
# 2025-04-09 00:11:35,641 INFO dune_client.api.base waiting for query execution 01JRBBA19D4Z9MYVY461K94KXC to complete: ExecutionState.EXECUTING
# 2025-04-09 00:11:36,829 INFO dune_client.api.base waiting for query execution 01JRBBA19D4Z9MYVY461K94KXC to complete: ExecutionState.EXECUTING
# 2025-04-09 00:11:38,071 INFO dune_client.api.base waiting for query execution 01JRBBA19D4Z9MYVY461K94KXC to complete: ExecutionState.EXECUTING
# 2025-04-09 00:11:39,251 INFO dune_client.api.base waiting for query execution 01JRBBA19D4Z9MYVY461K94KXC to complete: ExecutionState.EXECUTING
# 2025-04-09 00:11:40,438 INFO dune_client.api.base waiting for query execution 01JRBBA19D4Z9MYVY461K94KXC to complete: ExecutionState.EXECUTING
# 2025-04-09 00:11:41,623 INFO dune_client.api.base waiting for query execution 01JRBBA19D4Z9MYVY461K94KXC to complete: ExecutionState.EXECUTING
# 2025-04-09 00:11:42,805 INFO dune_client.api.base waiting for query execution 01JRBBA19D4Z9MYVY461K94KXC to complete: ExecutionState.EXECUTING
# 2025-04-09 00:11:43,986 INFO dune_client.api.base waiting for query execution 01JRBBA19D4Z9MYVY461K94KXC to complete: ExecutionState.EXECUTING
# 2025-04-09 00:11:45,199 INFO dune_client.api.base waiting for query execution 01JRBBA19D4Z9MYVY461K94KXC to complete: ExecutionState.EXECUTING
# 2025-04-09 00:11:46,381 INFO dune_client.api.base waiting for query execution 01JRBBA19D4Z9MYVY461K94KXC to complete: ExecutionState.EXECUTING

# %%
response_90d.head()
# Out:
#         coin  optimized_relative_strength  holder_now  three_month_change
# 0     KIZUNA                     3.113389      8492.0           -0.009102
# 1  DOGE(ETH)                     2.972326     34083.0            0.168947
# 2      HAPPY                     2.969645    113772.0           -0.086924
# 3       LUNA                     2.914792    303941.0            0.761609
# 4      TRUMP                     2.907812     51140.0            0.254169

# %%
## Implementing softmax weighting for timeframes
def softmax(x):
    """Compute softmax values for each set of scores in x."""
    e_x = np.exp(x - np.max(x))  # Subtract max for numerical stability
    return e_x / e_x.sum()

# Add after the softmax function definition

def detect_market_condition(rs_data):
    """
    Detect market condition based on relative strength patterns
    Returns: 'volatile', 'trending', or 'stable'
    """
    # Get the top 20 coins by 24h RS for analyzing recent movement
    top_recent = rs_data.sort_values('rs_24h', ascending=False).head(20)
    
    # Calculate the ratio between short-term and long-term RS
    top_recent['short_long_ratio'] = (top_recent['rs_24h'] + top_recent['rs_7d']) / \
                                     (top_recent['rs_90d'] + top_recent['rs_30d'] + 0.001)  # Avoid division by zero
    
    # Calculate metrics to determine market state
    avg_ratio = top_recent['short_long_ratio'].mean()
    ratio_std = top_recent['short_long_ratio'].std()
    
    # Determine market condition
    if ratio_std > 2.0:  # High variation between coins
        return 'volatile'
    elif avg_ratio > 3.0:  # Short-term RS much higher than long-term
        return 'trending'
    else:
        return 'stable'

# Add after the detect_market_condition function

def dynamic_weight_adjustment(rs_data, base_weights=None):
    """
    Dynamically adjust timeframe weights based on market conditions.
    
    Args:
        rs_data: DataFrame with RS values across timeframes
        base_weights: Optional base weights to modify (if None, uses default importance)
        
    Returns:
        adjusted_weights: np.array of adjusted weights after softmax
        market_condition: string indicating detected market condition
    """
    # Detect current market condition
    market_condition = detect_market_condition(rs_data)
    
    # Define importance adjustments based on market condition
    if market_condition == 'volatile':
        # In volatile markets, heavily favor very recent data (24h, 7d)
        importance = np.array([0.5, 1.0, 2.5, 3.5])  # 90d, 30d, 7d, 24h
        print("Volatile market detected - Increasing weight on recent timeframes")
        
    elif market_condition == 'trending':
        # In trending markets, balance recent and medium-term data
        importance = np.array([0.8, 1.5, 2.2, 2.8])  # 90d, 30d, 7d, 24h
        print("Trending market detected - Balanced weighting with emphasis on recent data")
        
    else:  # stable
        # In stable markets, give more weight to longer-term data
        importance = np.array([1.5, 1.8, 1.6, 1.7])  # 90d, 30d, 7d, 24h
        print("Stable market detected - More balanced weighting across timeframes")
    
    # Apply softmax to get normalized weights
    adjusted_weights = softmax(importance)
    
    return adjusted_weights, market_condition

def combine_timeframes_with_softmax(df_90d, df_30d, df_7d, df_24h, use_dynamic_weights=True):
    """Combine data from different time frames using softmax-weighted RS values."""
    # Merge all dataframes on 'coin' column
    combined_df = df_90d[['coin', 'optimized_relative_strength']].copy()
    combined_df.rename(columns={'optimized_relative_strength': 'rs_90d'}, inplace=True)
    
    # Merge with 30d data
    df_30d_subset = df_30d[['coin', 'optimized_relative_strength']].copy()
    df_30d_subset.rename(columns={'optimized_relative_strength': 'rs_30d'}, inplace=True)
    combined_df = combined_df.merge(df_30d_subset, on='coin', how='outer')
    
    # Merge with 7d data
    df_7d_subset = df_7d[['coin', 'optimized_relative_strength']].copy()
    df_7d_subset.rename(columns={'optimized_relative_strength': 'rs_7d'}, inplace=True)
    combined_df = combined_df.merge(df_7d_subset, on='coin', how='outer')
    
    # Merge with 24h data
    df_24h_subset = df_24h[['coin', 'optimized_relative_strength']].copy()
    df_24h_subset.rename(columns={'optimized_relative_strength': 'rs_24h'}, inplace=True)
    combined_df = combined_df.merge(df_24h_subset, on='coin', how='outer')
    
    # Fill NaN values with 0
    combined_df.fillna(0, inplace=True)
    
    if use_dynamic_weights:
        # Use dynamic weight adjustment based on market conditions
        weights, market_condition = dynamic_weight_adjustment(combined_df)
        combined_df['market_condition'] = market_condition
    else:
        # Use static weights (original implementation)
        importance = np.array([1.0, 1.5, 2.0, 2.5])  # Increasing importance: 90d, 30d, 7d, 24h
        weights = softmax(importance)
        combined_df['market_condition'] = 'static'
    
    # Calculate weighted RS
    combined_df['weighted_rs'] = (
        weights[0] * combined_df['rs_90d'] +
        weights[1] * combined_df['rs_30d'] +
        weights[2] * combined_df['rs_7d'] +
        weights[3] * combined_df['rs_24h']
    )
    
    # Sort by weighted RS
    combined_df.sort_values(by='weighted_rs', ascending=False, inplace=True)
    
    return combined_df, weights

# Combine data from all timeframes with dynamic softmax weights
combined_data, weights = combine_timeframes_with_softmax(
    response_90d, response_30d, response_7d, response_24h, 
    use_dynamic_weights=True  # Set to True to use dynamic weights
)

# Print the weights used
print(f"Timeframe weights (90d, 30d, 7d, 24h): {weights}")
print(f"Market condition: {combined_data['market_condition'].iloc[0]}")

# Create a function to prepare combined data for LLM
def prepare_combined_df_for_llm(df):
    # Select relevant columns for display
    relevant_df = df[['coin', 'rs_90d', 'rs_30d', 'rs_7d', 'rs_24h', 'weighted_rs']].head(15).copy()
    
    # Round values for better display
    for col in relevant_df.columns[1:]:
        relevant_df[col] = relevant_df[col].round(4)
    
    # Convert to markdown table
    markdown_table = relevant_df.to_markdown(index=False)
    return markdown_table
# Out:
# Volatile market detected - Increasing weight on recent timeframes
# Timeframe weights (90d, 30d, 7d, 24h): [0.03319688 0.0547324  0.2452936  0.66677713]
# Market condition: volatile

# %%
def compare_weight_strategies():
    """Compare different weighting strategies and their effect on top coin rankings"""
    # Get rankings with dynamic weights
    dynamic_df, dynamic_weights = combine_timeframes_with_softmax(
        response_90d, response_30d, response_7d, response_24h, 
        use_dynamic_weights=True
    )
    dynamic_top10 = dynamic_df[['coin', 'weighted_rs', 'market_condition']].head(10)
    dynamic_top10['rank'] = range(1, 11)
    dynamic_top10 = dynamic_top10[['rank', 'coin', 'weighted_rs', 'market_condition']]
    
    # Get rankings with static weights
    static_df, static_weights = combine_timeframes_with_softmax(
        response_90d, response_30d, response_7d, response_24h, 
        use_dynamic_weights=False
    )
    static_top10 = static_df[['coin', 'weighted_rs']].head(10)
    static_top10['rank'] = range(1, 11)
    static_top10 = static_top10[['rank', 'coin', 'weighted_rs']]
    
    # Create manual volatility scenario (double 24h importance)
    volatile_importance = np.array([0.5, 1.0, 2.0, 4.0])
    volatile_weights = softmax(volatile_importance)
    static_df['volatile_weighted_rs'] = (
        volatile_weights[0] * static_df['rs_90d'] +
        volatile_weights[1] * static_df['rs_30d'] +
        volatile_weights[2] * static_df['rs_7d'] +
        volatile_weights[3] * static_df['rs_24h']
    )
    static_df.sort_values(by='volatile_weighted_rs', ascending=False, inplace=True)
    volatile_top10 = static_df[['coin', 'volatile_weighted_rs']].head(10)
    volatile_top10['rank'] = range(1, 11)
    volatile_top10 = volatile_top10[['rank', 'coin', 'volatile_weighted_rs']]
    volatile_top10.rename(columns={'volatile_weighted_rs': 'weighted_rs'}, inplace=True)
    
    print("=== Dynamic Weights (Market Condition: {}) ===".format(dynamic_df['market_condition'].iloc[0]))
    print(f"Weights (90d, 30d, 7d, 24h): {dynamic_weights}")
    print(dynamic_top10)
    print("\n=== Static Weights (Original) ===")
    print(f"Weights (90d, 30d, 7d, 24h): {static_weights}")
    print(static_top10)
    print("\n=== High Volatility Scenario ===")
    print(f"Weights (90d, 30d, 7d, 24h): {volatile_weights}")
    print(volatile_top10)
    
    # Calculate changes in ranking
    diff_count = sum(1 for c1, c2 in zip(dynamic_top10['coin'], static_top10['coin']) if c1 != c2)
    print(f"\nDifference between dynamic and static: {diff_count} changes in top 10")
    
    # Return the different top coins
    dynamic_set = set(dynamic_top10['coin'])
    static_set = set(static_top10['coin'])
    volatile_set = set(volatile_top10['coin'])
    
    print("\nCoins uniquely in dynamic top 10:", dynamic_set - static_set)
    print("Coins uniquely in static top 10:", static_set - dynamic_set)
    print("Coins uniquely in volatile top 10:", volatile_set - static_set)
    
    return dynamic_top10, static_top10, volatile_top10

# Run the comparison
dynamic_top10, static_top10, volatile_top10 = compare_weight_strategies()
# Out:
# Volatile market detected - Increasing weight on recent timeframes
# === Dynamic Weights (Market Condition: volatile) ===
# Weights (90d, 30d, 7d, 24h): [0.03319688 0.0547324  0.2452936  0.66677713]
#     rank      coin  weighted_rs market_condition
# 27     1      LUCE    23.419287         volatile
# 47     2      PORK    20.146116         volatile
# 35     3       MOG    18.095165         volatile
# 50     4  RETARDIO    16.908027         volatile
# 63     5       USA    15.310045         volatile
# 3      6     BONGO    14.230764         volatile
# 49     7      PUPS    14.095668         volatile
# 5      8    BONSAI    10.203870         volatile
# 8      9    CHEEMS     7.195719         volatile
# 34    10     MOCHI     6.505288         volatile
#
# === Static Weights (Original) ===
# Weights (90d, 30d, 7d, 24h): [0.10153632 0.1674051  0.27600434 0.45505423]
#     rank      coin  weighted_rs
# 27     1      LUCE    19.727245
# 47     2      PORK    13.484161
# 35     3       MOG    12.079112
# 50     4  RETARDIO    11.482968
# 63     5       USA     9.857900
# 3      6     BONGO     9.627755
# 49     7      PUPS     9.324327
# 5      8    BONSAI     7.241195
# 8      9    CHEEMS     4.910850
# 56    10  SMURFCAT     4.352356
#
# === High Volatility Scenario ===
# Weights (90d, 30d, 7d, 24h): [0.02484727 0.04096623 0.11135776 0.82282873]
#     rank      coin  weighted_rs
# 47     1      PORK    25.277675
# 27     2      LUCE    25.117698
# 35     3       MOG    22.702506
# 50     4  RETARDIO    20.890209
# 63     5       USA    19.468097
# 49     6      PUPS    17.687545
# 3      7     BONGO    17.578536
# 5      8    BONSAI    12.447392
# 8      9    CHEEMS     8.879796
# 34    10     MOCHI     8.652181
#
# Difference between dynamic and static: 1 changes in top 10
#
# Coins uniquely in dynamic top 10: {'MOCHI'}
# Coins uniquely in static top 10: {'SMURFCAT'}
# Coins uniquely in volatile top 10: {'MOCHI'}

# %%
def generate_cot_analysis(coin_data, weights):
    """Generate a structured chain-of-thought analysis template for memecoin data."""
    timeframe_weights = {
        "90d": weights[0],
        "30d": weights[1],
        "7d": weights[2],
        "24h": weights[3]
    }
    
    cot_template = f"""
When analyzing memecoin performance, follow these reasoning steps:

1. TIMEFRAME WEIGHTS:
   - 90-day weight: {timeframe_weights['90d']:.4f} (longer-term trend)
   - 30-day weight: {timeframe_weights['30d']:.4f} (medium-term trend)
   - 7-day weight: {timeframe_weights['7d']:.4f} (short-term trend)
   - 24-hour weight: {timeframe_weights['24h']:.4f} (immediate momentum)

2. REASONING PROCESS:
   For each coin:
   - Examine its performance across all timeframes
   - Multiply each RS value by its corresponding weight
   - Calculate the contribution of each timeframe to the final score
   - Identify which timeframes drive the coin's ranking

3. CONSISTENCY ANALYSIS:
   - Coins with high RS values across multiple timeframes show consistent strength
   - Coins with recent spikes (high 24h/7d but low 90d/30d) show momentum but may lack longevity
   - Coins with high long-term metrics but low recent performance may be losing momentum

4. COMPARATIVE FRAMEWORK:
   - Compare coins against each other to establish relative performance
   - Place findings in context of the overall memecoin market
   - Evaluate which factors are most predictive for each coin's performance
"""
    
    return cot_template

# %% [markdown]
# # Creating the agent

# %% [markdown]
# ## Creating the model

# %%
from camel.models import ModelFactory
from camel.types import ModelPlatformType, ModelType

# Define the model, here in this case we use Gemini
model = ModelFactory.create(
    model_platform=ModelPlatformType.GEMINI,
    model_type=ModelType.GEMINI_2_0_FLASH,
)

# %% [markdown]
# ## Creating the Chat Agent

# %%
from camel.agents import ChatAgent

# Generate the CoT analysis template
cot_analysis = generate_cot_analysis(combined_data, weights)

# Prepare data
multi_timeframe_data = prepare_combined_df_for_llm(combined_data)

# Get market condition
market_condition = combined_data['market_condition'].iloc[0]

system_message = f"""You are a cryptocurrency analysis expert specializing in memecoins.
You have access to the following data about memecoins across multiple timeframes:

{multi_timeframe_data}

The data includes:
- 90-day relative strength (rs_90d)
- 30-day relative strength (rs_30d)
- 7-day relative strength (rs_7d)
- 24-hour relative strength (rs_24h)
- Weighted relative strength that emphasizes recent performance

Current market condition: {market_condition.upper()}
Based on this market condition, the weighting algorithm has {
    "increased the importance of recent data (24h, 7d)" if market_condition == 'volatile' else
    "balanced recent and medium-term data" if market_condition == 'trending' else
    "given more weight to longer-term performance"
}.

{cot_analysis}

When providing analysis, always:
1. Start with your INITIAL OBSERVATIONS of the data
2. Consider the current market condition ({market_condition}) in your analysis
3. THINK STEP-BY-STEP through your analysis of each coin's performance
4. SHOW YOUR CALCULATIONS for how each timeframe contributes to the weighted score
5. EXPLAIN YOUR REASONING for why certain coins rank higher than others
6. CONCLUDE with a clear summary and answer to the question

Format your reasoning in distinct sections so your analytical process is transparent.
Only use the data provided to you. If asked for information outside this dataset,
acknowledge the limitations of your data.
"""

agent = ChatAgent(
    system_message=system_message,
    model=model
)

# %% [markdown]
# ## Getting a sample response

# %%
# Generate a sample analysis with full chain-of-thought reasoning
detailed_question = """Analyze the top 10 memecoins in the dataset. 
For each coin:
1. Break down how each timeframe contributes to its weighted score
2. Calculate the percentage contribution from each timeframe
3. Explain whether its strength comes from consistent performance or recent momentum
4. Compare it to the other top coins
"""

response = agent.step(detailed_question)
print(response.msgs[0].content)
# Out:
# 2025-04-09 00:12:22,113 INFO httpx HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/openai/chat/completions "HTTP/1.1 200 OK"
# 2025-04-09 00:12:22,121 INFO camel.agents.chat_agent Model gemini-2.0-flash-exp, index 0, processed these messages: [{'role': 'system', 'content': "You are a cryptocurrency analysis expert specializing in memecoins.\nYou have access to the following data about memecoins across multiple timeframes:\n\n| coin     |   rs_90d |   rs_30d |   rs_7d |   rs_24h |   weighted_rs |\n|:---------|---------:|---------:|--------:|---------:|--------------:|\n| LUCE     |   1.1351 |  13.2063 | 17.8388 |  27.42   |       23.4193 |\n| PORK     |   1.7297 |  -1.2968 | -2.1428 |  31.0228 |       20.1461 |\n| MOG      |   2.6825 |  -2.1395 | -1.8749 |  27.8701 |       18.0952 |\n| RETARDIO |   2.5889 |  -1.9356 | -0.0802 |  25.4173 |       16.908  |\n| USA      |   1.7917 |  -3.3867 | -2.6851 |  24.1379 |       15.31   |\n| BONGO    |   2.8472 |  -2.375  |  0      |  21.3958 |       14.2308 |\n| PUPS     |   2.5703 |  -2.6832 | -1.3748 |  21.7381 |       14.0957 |\n| BONSAI   |   2.2689 |   0.3228 |  0.5196 |  14.9727 |       10.2039 |\n| CHEEMS   |   0      |   0      |  0      |  10.7918 |        7.1957 |\n| MOCHI    |  -0.2539 |  -2.4715 | -2.8986 |  11.0382 |        6.5053 |\n| GIGA     |   2.6228 |  -0.7411 | -2.6841 |   9.8241 |        5.9386 |\n| PEPECOIN |   0      |   0      |  0      |   8.859  |        5.907  |\n| FWOG     |   2.7057 |  -3.0855 | -2.7527 |   9.4149 |        5.5234 |\n| HAPPY    |   2.9696 |  -4.8069 |  0      |   7.5369 |        4.8609 |\n| GME      |   1.5985 |   0.8122 |  0.2532 |   7.0502 |        4.8605 |\n\nThe data includes:\n- 90-day relative strength (rs_90d)\n- 30-day relative strength (rs_30d)\n- 7-day relative strength (rs_7d)\n- 24-hour relative strength (rs_24h)\n- Weighted relative strength that emphasizes recent performance\n\nCurrent market condition: VOLATILE\nBased on this market condition, the weighting algorithm has increased the importance of recent data (24h, 7d).\n\n\nWhen analyzing memecoin performance, follow these reasoning steps:\n\n1. TIMEFRAME WEIGHTS:\n   - 90-day weight: 0.0332 (longer-term trend)\n   - 30-day weight: 0.0547 (medium-term trend)\n   - 7-day weight: 0.2453 (short-term trend)\n   - 24-hour weight: 0.6668 (immediate momentum)\n\n2. REASONING PROCESS:\n   For each coin:\n   - Examine its performance across all timeframes\n   - Multiply each RS value by its corresponding weight\n   - Calculate the contribution of each timeframe to the final score\n   - Identify which timeframes drive the coin's ranking\n\n3. CONSISTENCY ANALYSIS:\n   - Coins with high RS values across multiple timeframes show consistent strength\n   - Coins with recent spikes (high 24h/7d but low 90d/30d) show momentum but may lack longevity\n   - Coins with high long-term metrics but low recent performance may be losing momentum\n\n4. COMPARATIVE FRAMEWORK:\n   - Compare coins against each other to establish relative performance\n   - Place findings in context of the overall memecoin market\n   - Evaluate which factors are most predictive for each coin's performance\n\n\nWhen providing analysis, always:\n1. Start with your INITIAL OBSERVATIONS of the data\n2. Consider the current market condition (volatile) in your analysis\n3. THINK STEP-BY-STEP through your analysis of each coin's performance\n4. SHOW YOUR CALCULATIONS for how each timeframe contributes to the weighted score\n5. EXPLAIN YOUR REASONING for why certain coins rank higher than others\n6. CONCLUDE with a clear summary and answer to the question\n\nFormat your reasoning in distinct sections so your analytical process is transparent.\nOnly use the data provided to you. If asked for information outside this dataset,\nacknowledge the limitations of your data.\n"}, {'role': 'user', 'content': 'Analyze the top 10 memecoins in the dataset. \nFor each coin:\n1. Break down how each timeframe contributes to its weighted score\n2. Calculate the percentage contribution from each timeframe\n3. Explain whether its strength comes from consistent performance or r ...
# Okay, I will analyze the top 10 memecoins in the dataset based on their weighted relative strength, considering the volatile market conditions and the increased importance of recent data.
#
# **Initial Observations:**
#
# The top 10 coins show positive weighted relative strength, indicating they've generally outperformed other memecoins recently. LUCE and PORK have the highest weighted scores, suggesting strong recent performance. Several coins (MOG, RETARDIO, USA, BONGO, PUPS) show negative 30-day and 7-day RS but high 24-hour RS, implying a recent surge in momentum.
#
# **Memecoin Analysis:**
#
# I will now analyze each of the top 10 memecoins, breaking down their weighted scores and assessing the consistency of their performance.
#
# **1. LUCE:**
#
# *   **Timeframe Contributions:**
#     *   90-day: 1.1351 * 0.0332 = 0.0377
#     *   30-day: 13.2063 * 0.0547 = 0.7224
#     *   7-day: 17.8388 * 0.2453 = 4.3758
#     *   24-hour: 27.42 * 0.6668 = 18.2701
# *   **Percentage Contribution:**
#     *   90-day: (0.0377 / 23.4193) * 100 = 0.16%
#     *   30-day: (0.7224 / 23.4193) * 100 = 3.08%
#     *   7-day: (4.3758 / 23.4193) * 100 = 18.68%
#     *   24-hour: (18.2701 / 23.4193) * 100 = 78.01%
# *   **Strength Assessment:** LUCE's strength is heavily driven by its recent 24-hour performance, with a significant contribution from its 7-day performance. While it shows positive momentum across all timeframes, the 24h and 7d are what are driving the ranking.
# *   **Comparative Analysis:** LUCE's weighted score is the highest among the top 10, indicating the strongest recent momentum. Its higher 30-day and 7-day RS compared to others (like MOG or RETARDIO) suggests more sustained positive performance in the short to medium term.
#
# **2. PORK:**
#
# *   **Timeframe Contributions:**
#     *   90-day: 1.7297 * 0.0332 = 0.0574
#     *   30-day: -1.2968 * 0.0547 = -0.0709
#     *   7-day: -2.1428 * 0.2453 = -0.5256
#     *   24-hour: 31.0228 * 0.6668 = 20.6813
# *   **Percentage Contribution:**
#     *   90-day: (0.0574 / 20.1461) * 100 = 0.29%
#     *   30-day: (-0.0709 / 20.1461) * 100 = -0.35%
#     *   7-day: (-0.5256 / 20.1461) * 100 = -2.61%
#     *   24-hour: (20.6813 / 20.1461) * 100 = 102.66%
# *   **Strength Assessment:** PORK's strength is almost entirely due to its exceptional 24-hour performance, which offsets negative performance in the 30-day and 7-day timeframes. This suggests very recent and strong momentum.
# *   **Comparative Analysis:** While PORK has a strong 24h, its negative short-term and medium-term relative strength indicate it is not a consistent performer.
#
# **3. MOG:**
#
# *   **Timeframe Contributions:**
#     *   90-day: 2.6825 * 0.0332 = 0.0891
#     *   30-day: -2.1395 * 0.0547 = -0.1170
#     *   7-day: -1.8749 * 0.2453 = -0.4594
#     *   24-hour: 27.8701 * 0.6668 = 18.5898
# *   **Percentage Contribution:**
#     *   90-day: (0.0891 / 18.0952) * 100 = 0.49%
#     *   30-day: (-0.1170 / 18.0952) * 100 = -0.65%
#     *   7-day: (-0.4594 / 18.0952) * 100 = -2.54%
#     *   24-hour: (18.5898 / 18.0952) * 100 = 102.73%
# *   **Strength Assessment:** Similar to PORK, MOG's ranking is overwhelmingly influenced by its 24-hour surge, overpowering negative short-term and medium-term performance.
# *   **Comparative Analysis:** MOG and PORK show a similar performance profile, with recent spikes outweighing negative trends in other timeframes.
#
# **4. RETARDIO:**
#
# *   **Timeframe Contributions:**
#     *   90-day: 2.5889 * 0.0332 = 0.0859
#     *   30-day: -1.9356 * 0.0547 = -0.1060
#     *   7-day: -0.0802 * 0.2453 = -0.0197
#     *   24-hour: 25.4173 * 0.6668 = 16.9548
# *   **Percentage Contribution:**
#     *   90-day: (0.0859 / 16.908) * 100 = 0.51%
#     *   30-day: (-0.1060 / 16.908) * 100 = -0.63%
#     *   7-day: (-0.0197 / 16.908) * 100 = -0.12%
#     *   24-hour: (16.9548 / 16.908) * 100 = 100.28%
# *   **Strength Assessment:** RETARDIO's performance is overwhelmingly reliant on its 24-hour surge, which overshadows negative or negligible performance in other timeframes.
# *   **Comparative Analysis:** RETARDIO shows a very similar pattern to MOG and PORK, where recent momentum is the primary driver.
#
# **5. USA:**
#
# *   **Timeframe Contributions:**
#     *   90-day: 1.7917 * 0.0332 = 0.0595
#     *   30-day: -3.3867 * 0.0547 = -0.1852
#     *   7-day: -2.6851 * 0.2453 = -0.6587
#     *   24-hour: 24.1379 * 0.6668 = 16.0969
# *   **Percentage Contribution:**
#     *   90-day: (0.0595 / 15.31) * 100 = 0.39%
#     *   30-day: (-0.1852 / 15.31) * 100 = -1.21%
#     *   7-day: (-0.6587 / 15.31) * 100 = -4.30%
#     *   24-hour: (16.0969 / 15.31) * 100 = 105.14%
# *   **Strength Assessment:** Like the previous coins, USA's high ranking is primarily due to its 24-hour performance, compensating for negative performance in the 30-day and 7-day timeframes.
# *   **Comparative Analysis:** The pattern is consistent - a strong 24h performance dominates, while other timeframes detract slightly from the overall weighted score.
#
# **6. BONGO:**
#
# *   **Timeframe Contributions:**
#     *   90-day: 2.8472 * 0.0332 = 0.0945
#     *   30-day: -2.375 * 0.0547 = -0.1300
#     *   7-day: 0 * 0.2453 = 0
#     *   24-hour: 21.3958 * 0.6668 = 14.2697
# *   **Percentage Contribution:**
#     *   90-day: (0.0945 / 14.2308) * 100 = 0.66%
#     *   30-day: (-0.1300 / 14.2308) * 100 = -0.91%
#     *   7-day: (0 / 14.2308) * 100 = 0%
#     *   24-hour: (14.2697 / 14.2308) * 100 = 100.27%
# *   **Strength Assessment:** BONGO's ranking is almost entirely driven by its 24-hour performance.
# *   **Comparative Analysis:** This coin follows the trend of the others. The 24h performance is the only thing pushing the coin upwards.
#
# **7. PUPS:**
#
# *   **Timeframe Contributions:**
#     *   90-day: 2.5703 * 0.0332 = 0.0853
#     *   30-day: -2.6832 * 0.0547 = -0.1468
#     *   7-day: -1.3748 * 0.2453 = -0.3372
#     *   24-hour: 21.7381 * 0.6668 = 14.5091
# *   **Percentage Contribution:**
#     *   90-day: (0.0853 / 14.0957) * 100 = 0.61%
#     *   30-day: (-0.1468 / 14.0957) * 100 = -1.04%
#     *   7-day: (-0.3372 / 14.0957) * 100 = -2.39%
#     *   24-hour: (14.5091 / 14.0957) * 100 = 102.93%
# *   **Strength Assessment:** PUPS' ranking is overwhelmingly driven by its 24-hour surge, counteracting negative performance in the 30-day and 7-day timeframes.
# *   **Comparative Analysis:** 24h performance driving the score.
#
# **8. BONSAI:**
#
# *   **Timeframe Contributions:**
#     *   90-day: 2.2689 * 0.0332 = 0.0753
#     *   30-day: 0.3228 * 0.0547 = 0.0176
#     *   7-day: 0.5196 * 0.2453 = 0.1274
#     *   24-hour: 14.9727 * 0.6668 = 9.9855
# *   **Percentage Contribution:**
#     *   90-day: (0.0753 / 10.2039) * 100 = 0.74%
#     *   30-day: (0.0176 / 10.2039) * 100 = 0.17%
#     *   7-day: (0.1274 / 10.2039) * 100 = 1.25%
#     *   24-hour: (9.9855 / 10.2039) * 100 = 97.86%
# *   **Strength Assessment:** BONSAI's strength comes almost entirely from its recent 24-hour performance.
# *   **Comparative Analysis:** BONSAI's 24h performance has far more influence.
#
# **9. CHEEMS:**
#
# *   **Timeframe Contributions:**
#     *   90-day: 0 * 0.0332 = 0
#     *   30-day: 0 * 0.0547 = 0
#     *   7-day: 0 * 0.2453 = 0
#     *   24-hour: 10.7918 * 0.6668 = 7.1957
# *   **Percentage Contribution:**
#     *   90-day: (0 / 7.1957) * 100 = 0%
#     *   30-day: (0 / 7.1957) * 100 = 0%
#     *   7-day: (0 / 7.1957) * 100 = 0%
#     *   24-hour: (7.1957 / 7.1957) * 100 = 100%
# *   **Strength Assessment:** CHEEMS' performance relies entirely on the 24-hour.
# *   **Comparative Analysis:** Its lower weighted score reflects the lack of prior momentum.
#
# **10. MOCHI:**
#
# *   **Timeframe Contributions:**
#     *   90-day: -0.2539 * 0.0332 = -0.0084
#     *   30-day: -2.4715 * 0.0547 = -0.1352
#     *   7-day: -2.8986 * 0.2453 = -0.7110
#     *   24-hour: 11.0382 * 0.6668 = 7.3614
# *   **Percentage Contribution:**
#     *   90-day: (-0.0084 / 6.5053) * 100 = -0.13%
#     *   30-day: (-0.1352 / 6.5053) * 100 = -2.08%
#     *   7-day: (-0.7110 / 6.5053) * 100 = -10.93%
#     *   24-hour: (7.3614 / 6.5053) * 100 = 113.16%
# *   **Strength Assessment:** MOCHI's ranking is predominantly influenced by its 24-hour performance.
# *   **Comparative Analysis:** MOCHI is similar to many of the other coins in the top 10, relying on its 24h performance.
#
# **Conclusion:**
#
# In the current volatile market conditions, the top 10 memecoins are primarily ranked based on their recent 24-hour performance. While a few (like LUCE and BONSAI) show some supporting momentum from the 7-day and 30-day timeframes, the majority are experiencing a short-term surge that overshadows previous negative or neutral performance. This suggests that these coins may be highly susceptible to market fluctuations and that their current rankings may not be sustainable in the long term without more consistent positive momentum. PORK, MOG, RETARDIO, USA, BONGO, PUPS, CHEEMS, and MOCHI are overwhelmingly dependent on their 24-hour surge.
